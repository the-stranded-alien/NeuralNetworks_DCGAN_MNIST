# %%
from keras.datasets import mnist
from keras.layers import *
from keras.layers.advanced_activations import LeakyReLU
from keras.models import Sequential, Model
from keras.optimizers import Adam

import matplotlib.pyplot as plt
import math
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
(X_Train,_),(_,_) = mnist.load_data()
# Out:
# Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# 11493376/11490434 [==============================] - 1s 0us/step

# %%
print(X_Train.shape)
print(type(X_Train))

X_Train = X_Train.reshape((*X_Train.shape, 1))
print(X_Train.shape)
# Out:
# (60000, 28, 28)
# <class 'numpy.ndarray'>
# (60000, 28, 28, 1)

# %%
# Normalize the Data between -1 and 1

X_Train = (X_Train.astype('float32') - 127.5)/127.5

print(np.min(X_Train))
print(np.max(X_Train))
# Out:
# -1.0
# 1.0

# %%
TOTAL_EPOCHS = 50
BATCH_SIZE = 256
NO_OF_BATCHES = math.ceil(X_Train.shape[0]/float(BATCH_SIZE))
HALF_BATCH = int(BATCH_SIZE/2)

NOISE_DIM = 100

# Use these Adam Params for GAN's
adam = Adam(lr=2e-4, beta_1=0.5)

# %%
# Generator

generator = Sequential()
generator.add(Dense(7*7*128, input_shape=(NOISE_DIM,)))
generator.add(Reshape((7,7,128)))
generator.add(LeakyReLU(0.2))
generator.add(BatchNormalization())

# Double Activation Size (14 * 14 * 64)
generator.add(UpSampling2D())
generator.add(Conv2D(64, kernel_size=(5,5), padding='same'))
generator.add(LeakyReLU(0.2))
generator.add(BatchNormalization())

# Double Activation Size (28 * 28 * 1)
generator.add(UpSampling2D())
generator.add(Conv2D(1, kernel_size=(5,5), padding='same', activation='tanh'))
generator.compile(loss='binary_crossentropy', optimizer='adam')
generator.summary()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0831 13:01:57.161806 140274816456576 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0831 13:01:57.163902 140274816456576 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0831 13:01:57.167891 140274816456576 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0831 13:01:57.211461 140274816456576 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0831 13:01:57.212604 140274816456576 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0831 13:02:00.516216 140274816456576 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0831 13:02:00.608749 140274816456576 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2239: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# W0831 13:02:00.735993 140274816456576 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0831 13:02:00.761623 140274816456576 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 6272)              633472
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 7, 7, 128)         0
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 7, 7, 128)         0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 7, 7, 128)         512
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 64)        204864
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 14, 14, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 14, 14, 64)        256
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 1)         1601
# =================================================================
# Total params: 840,705
# Trainable params: 840,321
# Non-trainable params: 384
# _________________________________________________________________

# %%
# Discriminator

discriminator = Sequential()
discriminator.add(Conv2D(64,(5,5), strides=(2,2), padding='same', input_shape=(28,28,1)))
discriminator.add(LeakyReLU(0.2))

# Next Conv Layer (14 x 14 x 64)
discriminator.add(Conv2D(128, (5,5), strides=(2,2), padding='same'))
discriminator.add(LeakyReLU(0.2))

# Flatten
discriminator.add(Flatten())
discriminator.add(Dense(1, activation='sigmoid'))
discriminator.compile(loss='binary_crossentropy', optimizer='adam')
discriminator.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 14, 14, 64)        1664
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 7, 7, 128)         204928
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 6272)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 6273
# =================================================================
# Total params: 212,865
# Trainable params: 212,865
# Non-trainable params: 0
# _________________________________________________________________

# %%
# GAN (Step-2)
discriminator.trainable = False
gan_input = Input(shape=(NOISE_DIM,))
generated_img = generator(gan_input)
gan_output = discriminator(generated_img)

# Functional API
model = Model(gan_input, gan_output)
model.compile(loss='binary_crossentropy', optimizer=adam)
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 100)               0
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 28, 28, 1)         840705
# _________________________________________________________________
# sequential_2 (Sequential)    (None, 1)                 212865
# =================================================================
# Total params: 1,053,570
# Trainable params: 840,321
# Non-trainable params: 213,249
# _________________________________________________________________

# %%
def save_images(epoch, samples=100):
    
    noise = np.random.normal(0,1,size=(samples, NOISE_DIM))
    generated_imgs = generator.predict(noise)
    generated_imgs = generated_imgs.reshape(samples,28,28)
    
    plt.figure(figsize=(10,10))
    for i in range(samples):
        plt.subplot(10,10,i+1)
        plt.imshow(generated_imgs[i], interpolation='nearest', cmap='gray')
        plt.axis("off")
        
    plt.tight_layout()
    plt.savefig('images/dcgan_output_epoch_{0}.png'.format(epoch+1))
    plt.show()

# %%
# !mkdir images
# !mkdir model

# %%
# !ls
# Out:
# images	model  sample_data

# %%
# Training Loop
d_losses = []
g_losses = []

for epoch in range(TOTAL_EPOCHS):
    epoch_d_loss = 0.0
    epoch_g_loss = 0.0
    
    # Mini Batch SGD
    for step in range(NO_OF_BATCHES):
        
        # Step-1 Discriminator
        # 50% Real Data + 50% Fake Data
        
        # Real Data X
        # idx = np.random.randint(low, high, no_of_numbers)
        idx = np.random.randint(0, X_Train.shape[0], HALF_BATCH)
        real_imgs = X_Train[idx]
        
        # Fake Data X
        noise = np.random.normal(0,1,size=(HALF_BATCH, NOISE_DIM))
        fake_imgs = generator.predict(noise) # Forward
        
        # Labels
        real_y = np.ones((HALF_BATCH, 1)) * 0.9 # One sided label smoothing for Discriminator
        fake_y = np.zeros((HALF_BATCH, 1))
        
        # Train our Discriminator
        
        d_loss_real = discriminator.train_on_batch(real_imgs, real_y)
        d_loss_fake = discriminator.train_on_batch(fake_imgs, fake_y)
        d_loss = (0.5 * d_loss_real) + (0.5 * d_loss_fake)
        
        epoch_d_loss += d_loss
        
        # Step-2 : Train Generator (Considering Frozen Discriminator)
        noise = np.random.normal(0,1,size=(BATCH_SIZE, NOISE_DIM))
        ground_truth_y = np.ones((BATCH_SIZE,1))
        g_loss = model.train_on_batch(noise, ground_truth_y)
        epoch_g_loss += g_loss
    
    print("Epoch %d -> Discriminator Loss : %.4f & Generator Loss : %.4f"%((epoch+1),(epoch_d_loss/NO_OF_BATCHES),(epoch_g_loss/NO_OF_BATCHES)))
    d_losses.append(epoch_d_loss/NO_OF_BATCHES)
    g_losses.append(epoch_g_loss/NO_OF_BATCHES)
    
    if(epoch+1)%5 == 0:
        generator.save('model/dcgan_generator_{0}.h5'.format(epoch+1))
        save_images(epoch)
# Out:
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:493: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:493: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:493: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# Epoch 1 -> Discriminator Loss : 0.5574 & Generator Loss : 2.1569
# Epoch 2 -> Discriminator Loss : 0.6895 & Generator Loss : 1.0138
# Epoch 3 -> Discriminator Loss : 0.6238 & Generator Loss : 1.1456
# Epoch 4 -> Discriminator Loss : 0.5974 & Generator Loss : 1.3303
# Epoch 5 -> Discriminator Loss : 0.6461 & Generator Loss : 1.1148
# Epoch 6 -> Discriminator Loss : 0.6502 & Generator Loss : 1.0426
# Epoch 7 -> Discriminator Loss : 0.6481 & Generator Loss : 1.0294
# Epoch 8 -> Discriminator Loss : 0.6557 & Generator Loss : 1.0397
# Epoch 9 -> Discriminator Loss : 0.6426 & Generator Loss : 1.0395
# Epoch 10 -> Discriminator Loss : 0.6490 & Generator Loss : 1.0566
# Epoch 11 -> Discriminator Loss : 0.6474 & Generator Loss : 1.0526
# Epoch 12 -> Discriminator Loss : 0.6499 & Generator Loss : 1.0734
# Epoch 13 -> Discriminator Loss : 0.6444 & Generator Loss : 1.0743
# Epoch 14 -> Discriminator Loss : 0.6408 & Generator Loss : 1.0822
# Epoch 15 -> Discriminator Loss : 0.6422 & Generator Loss : 1.1071
# Epoch 16 -> Discriminator Loss : 0.6305 & Generator Loss : 1.1113
# Epoch 17 -> Discriminator Loss : 0.6364 & Generator Loss : 1.1262
# Epoch 18 -> Discriminator Loss : 0.6229 & Generator Loss : 1.1441
# Epoch 19 -> Discriminator Loss : 0.6139 & Generator Loss : 1.1718
# Epoch 20 -> Discriminator Loss : 0.6117 & Generator Loss : 1.1930
# Epoch 21 -> Discriminator Loss : 0.6115 & Generator Loss : 1.2217
# Epoch 22 -> Discriminator Loss : 0.5986 & Generator Loss : 1.2406
# Epoch 23 -> Discriminator Loss : 0.5971 & Generator Loss : 1.2570
# Epoch 24 -> Discriminator Loss : 0.5889 & Generator Loss : 1.2821
# Epoch 25 -> Discriminator Loss : 0.5830 & Generator Loss : 1.3136
# Epoch 26 -> Discriminator Loss : 0.5776 & Generator Loss : 1.3354
# Epoch 27 -> Discriminator Loss : 0.5751 & Generator Loss : 1.3777
# Epoch 28 -> Discriminator Loss : 0.5588 & Generator Loss : 1.4066
# Epoch 29 -> Discriminator Loss : 0.5516 & Generator Loss : 1.4433
# Epoch 30 -> Discriminator Loss : 0.5555 & Generator Loss : 1.4761
# Epoch 31 -> Discriminator Loss : 0.5465 & Generator Loss : 1.5033
# Epoch 32 -> Discriminator Loss : 0.5397 & Generator Loss : 1.5224
# Epoch 33 -> Discriminator Loss : 0.5309 & Generator Loss : 1.5555
# Epoch 34 -> Discriminator Loss : 0.5334 & Generator Loss : 1.5903
# Epoch 35 -> Discriminator Loss : 0.5181 & Generator Loss : 1.6129
# Epoch 36 -> Discriminator Loss : 0.5166 & Generator Loss : 1.6614
# Epoch 37 -> Discriminator Loss : 0.5076 & Generator Loss : 1.6781
# Epoch 38 -> Discriminator Loss : 0.5049 & Generator Loss : 1.7357
# Epoch 39 -> Discriminator Loss : 0.4930 & Generator Loss : 1.7717
# Epoch 40 -> Discriminator Loss : 0.4927 & Generator Loss : 1.8320
# Epoch 41 -> Discriminator Loss : 0.4983 & Generator Loss : 1.8602
# Epoch 42 -> Discriminator Loss : 0.4862 & Generator Loss : 1.8666
# Epoch 43 -> Discriminator Loss : 0.4742 & Generator Loss : 1.8897
# Epoch 44 -> Discriminator Loss : 0.4790 & Generator Loss : 1.9482
# Epoch 45 -> Discriminator Loss : 0.4789 & Generator Loss : 1.9626
# Epoch 46 -> Discriminator Loss : 0.4737 & Generator Loss : 1.9951
# Epoch 47 -> Discriminator Loss : 0.4675 & Generator Loss : 1.9865
# Epoch 48 -> Discriminator Loss : 0.4565 & Generator Loss : 2.0425
# Epoch 49 -> Discriminator Loss : 0.4552 & Generator Loss : 2.0789
# Epoch 50 -> Discriminator Loss : 0.4646 & Generator Loss : 2.1222

# %%
# !zip -r /content/images.zip /content/images
# Out:
#   adding: content/images/ (stored 0%)
#   adding: content/images/gan_output_epoch_45.png (deflated 9%)
#   adding: content/images/gan_output_epoch_20.png (deflated 8%)
#   adding: content/images/gan_output_epoch_25.png (deflated 8%)
#   adding: content/images/gan_output_epoch_5.png (deflated 8%)
#   adding: content/images/gan_output_epoch_15.png (deflated 8%)
#   adding: content/images/gan_output_epoch_40.png (deflated 8%)
#   adding: content/images/gan_output_epoch_10.png (deflated 8%)
#   adding: content/images/gan_output_epoch_30.png (deflated 8%)
#   adding: content/images/gan_output_epoch_35.png (deflated 8%)
#   adding: content/images/gan_output_epoch_50.png (deflated 8%)

# %%
from google.colab import files

# %%
files.download('images.zip')

# %%
plt.plot(d_losses,label="Discriminator Loss")
plt.plot(g_losses,label="Generator Loss")
plt.legend()
plt.show()

# %%
# !zip -r /content/model.zip /content/model
# Out:
#   adding: content/model/ (stored 0%)
#   adding: content/model/gan_generator_15.h5 (deflated 8%)
#   adding: content/model/gan_generator_25.h5 (deflated 8%)
#   adding: content/model/gan_generator_20.h5 (deflated 8%)
#   adding: content/model/gan_generator_30.h5 (deflated 8%)
#   adding: content/model/gan_generator_10.h5 (deflated 8%)
#   adding: content/model/gan_generator_40.h5 (deflated 8%)
#   adding: content/model/gan_generator_5.h5 (deflated 8%)
#   adding: content/model/gan_generator_35.h5 (deflated 8%)
#   adding: content/model/gan_generator_45.h5 (deflated 8%)
#   adding: content/model/gan_generator_50.h5 (deflated 8%)

# %%
files.download('model.zip')
